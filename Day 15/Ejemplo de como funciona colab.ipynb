# %%
print(nombre)
# Out:
# Alfonso

# %%
nombre = "Alfonso"
edad = 45

# %% [markdown]
# Esto es solo un texto que no es ejecutable, solo aparece en pantalla.

# %%
nombre = 'Pedro'

# %%
def mostrar_nombre(persona):
  print("Hola " + persona)

# %%
mostrar_nombre("Fernando")
# Out:
# HolaFernando
